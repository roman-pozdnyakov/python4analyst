# %% [markdown]
# ## Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# ### 1.1. Скачать исходные данные: kc-house-data

# %%
# подготовка
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')
df.sample()
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 8903  3578600201  20140731T000000  650000.0         4        2.5         2860
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 8903      5576     2.0           0     0  ...      8        2860
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat     long  \
# 8903              0      2004             0    98028  47.745 -122.224
#
#       sqft_living15  sqft_lot15
# 8903           2290       10667
#
# [1 rows x 21 columns]

# %% [markdown]
# ### 1.2. Изучите стоимости недвижимости

# %%
plt.figure(figsize=(20, 10))
plt.hist(df['price'], bins=100)
plt.title('Распределение стоимости недвижимости')
plt.ylabel('Количество')
plt.xlabel('Цена')
plt.xticks(range(0, 7700000, 100000))
plt.xticks(rotation=90);

# %% [markdown]
# <u>*Вывод:*</u>  Стоимость недвижимости в основном распределена вокруг значения 400тыс долларов США с минимальной границей примерно 100тыс и выбросом по максимуму до 7.7 млн.

# %%
sns.boxplot(df["price"]);

# %% [markdown]
# <u>*Вывод:*</u>  99.7% предложений находятся в диапазоне 0,1 ... 1,2млн долларов США.

# %% [markdown]
# ### 1.3. Изучите распределение квадратуры жилой

# %%
sns.histplot(df['sqft_living']);

# %%
plt.boxplot(df['sqft_living'])
plt.title('Распределение жилой площади')
plt.yticks(range(0, 14500, 1000))
plt.ylabel('Количество')
plt.xlabel('Жилая площадь');

# %% [markdown]
# <i><u>Вывод: </u></i> 99.7% Жилой площади находится в интервале примерно от 500 до 4400 квадратных футов (50-400 кв. метров), остальные 0,3% предложений приходятся на объекты с большей площадью (в основном 4400-8000 кв.футов, единичные предложения с жилой площадью от 8000 до 13540 кв. футов (1258 кв.метров))

# %% [markdown]
# ### 1.4. Изучите распределение года постройки

# %%
plt.figure(figsize=(15, 7))
plt.hist(df['yr_built'], bins=100)
plt.title('Распределение года постройки')
plt.ylabel('Количество')
plt.xlabel('Год постройки')
#plt.xticks(range(0, 7700000, 100000))
plt.xticks(rotation=90);

# %% [markdown]
# В целом, с увеличением возраста невдижимости, количество предложений уменьшается (дома ветшают, их сносят для постройки новых зданий). Также этот график хорошо иллюстрирует связь общеэкономической ситуацией со строительным бизнесом - начиная от провала 1930х годов (великая депрессия), заканчивая недавними взлётами и падениями (рост после кризиса конца 1990х с резким взлётом непосредственно перед кризисом 2008-го).

# %%
df['yr_built'].median()
# Out:
# 1975.0

# %%
sns.boxplot(df["yr_built"]);

# %% [markdown]
# График распределения предложений показывает, что основное количество (второй и третий квартиль) приходятся на недвижимость постройки 1950-1995 годов постройки с медианной 1975.

# %% [markdown]
# ## Задача 2
# ### 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы

# %% [markdown]
# ### 2.2. Изучите распределение этажей домов

# %% [markdown]
# ### 2.3. Изучите распределение состояния домов

# %% [markdown]
# ## Задача 3
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.
#
# Данная промежуточная аттестация оценивается по системе "зачет" / "не зачет".
# "Зачет" ставится, если слушатель успешно выполнил 3 или 2 критерия.
# "Незачет" ставится, если слушатель успешно выполнил 1 или меньше критериев.
#
# Критерии оценивания:
# - слушатель верно подгрузил данные в библиотеку
# - слушатель сформировал корректный график по данным
# - слушатель проанализировал данные и сделал корректный вывод
